# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_location="C:\\Users\\Greeshma\\OneDrive\\Naresh IT\\files\\Visadataset - Visadataset.csv"
visa_df=pd.read_csv(file_location)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df["prevailing_wage"]
# Out:
# 0           592.2029
# 1         83425.6500
# 2        122996.8600
# 3         83434.0300
# 4        149907.3900
#             ...
# 25475     77092.5700
# 25476    279174.7900
# 25477    146298.8500
# 25478     86154.7700
# 25479     70876.9100
# Name: prevailing_wage, Length: 25480, dtype: float64

# %%
# to deal with the outliers
# Drop : Not reccomonded >2% 
# Median value: outliers doesn not effect median value
# Two types of dataframes are there
# outliers_df and non_outliers_df

# %%
Q1=np.quantile(visa_df["prevailing_wage"],0.25)
Q2=np.quantile(visa_df["prevailing_wage"],0.50)
Q3=np.quantile(visa_df["prevailing_wage"],0.75)

IQR=Q3-Q1
UB=Q3+1.5*IQR
LB=Q1-1.5*IQR

############# Outliers_df #####################
con1=visa_df["prevailing_wage"]>UB
con2=visa_df["prevailing_wage"]<LB
outliers_df=visa_df[con1 | con2]

############### non_outliers_df ###############
con11=visa_df["prevailing_wage"]<UB
con22=visa_df["prevailing_wage"]>LB
non_outliers_df=visa_df[con11 & con22]

# %%
outliers_df
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 14        EZYV15           Asia              Master's                  Y
# 34        EZYV35           Asia              Master's                  N
# 130      EZYV131  South America           High School                  N
# 216      EZYV217           Asia              Master's                  Y
# 221      EZYV222  North America             Doctorate                  Y
# ...          ...            ...                   ...                ...
# 25191  EZYV25192           Asia              Master's                  N
# 25195  EZYV25196  North America              Master's                  Y
# 25468  EZYV25469           Asia            Bachelor's                  N
# 25469  EZYV25470  North America              Master's                  Y
# 25476  EZYV25477           Asia           High School                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
len(outliers_df)
# Out:
# 427

# %%
non_outliers_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25474  EZYV25475    Africa             Doctorate                  N
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
len(non_outliers_df)
# Out:
# 25053

# %% [markdown]
# # Replacing Outliers by median value #

# %%
visa_df[['prevailing_wage']].median()
# Out:
# prevailing_wage    70308.21
# dtype: float64

# %%
visa_df['prevailing_wage'].median()
# Out:
# 70308.20999999999

# %%
outliers_df['prevailing_wage']=visa_df['prevailing_wage'].median()
modified_df=outliers_df
modified_df
# Out:
# C:\Users\Greeshma\AppData\Local\Temp\ipykernel_19404\1587345797.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_df['prevailing_wage']=visa_df['prevailing_wage'].median()
#          case_id      continent education_of_employee has_job_experience  \
# 14        EZYV15           Asia              Master's                  Y
# 34        EZYV35           Asia              Master's                  N
# 130      EZYV131  South America           High School                  N
# 216      EZYV217           Asia              Master's                  Y
# 221      EZYV222  North America             Doctorate                  Y
# ...          ...            ...                   ...                ...
# ...

# %%
# now we have non_outliers_df and the modified_df
# we need to merge or combine or concatenate 
# Outer join = A outer B
# Inner join = A intersection B
final_df=pd.merge( non_outliers_df, modified_df,how="outer")
final_df
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 0         EZYV01           Asia           High School                  N
# 1         EZYV02           Asia              Master's                  Y
# 2         EZYV03           Asia            Bachelor's                  N
# 3         EZYV04           Asia            Bachelor's                  N
# 4         EZYV05         Africa              Master's                  Y
# ...          ...            ...                   ...                ...
# 25475  EZYV25192           Asia              Master's                  N
# 25476  EZYV25196  North America              Master's                  Y
# 25477  EZYV25469           Asia            Bachelor's                  N
# 25478  EZYV25470  North America              Master's                  Y
# 25479  EZYV25477           Asia           High School                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
# merge two data frames 
d1=modified_df
d2=non_outliers_df
pd.merge(d2,d1,how="outer")
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 0         EZYV01           Asia           High School                  N
# 1         EZYV02           Asia              Master's                  Y
# 2         EZYV03           Asia            Bachelor's                  N
# 3         EZYV04           Asia            Bachelor's                  N
# 4         EZYV05         Africa              Master's                  Y
# ...          ...            ...                   ...                ...
# 25475  EZYV25192           Asia              Master's                  N
# 25476  EZYV25196  North America              Master's                  Y
# 25477  EZYV25469           Asia            Bachelor's                  N
# 25478  EZYV25470  North America              Master's                  Y
# 25479  EZYV25477           Asia           High School                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
pd.concat([d1,d2])
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 14        EZYV15           Asia              Master's                  Y
# 34        EZYV35           Asia              Master's                  N
# 130      EZYV131  South America           High School                  N
# 216      EZYV217           Asia              Master's                  Y
# 221      EZYV222  North America             Doctorate                  Y
# ...          ...            ...                   ...                ...
# 25474  EZYV25475         Africa             Doctorate                  N
# 25475  EZYV25476           Asia            Bachelor's                  Y
# 25477  EZYV25478           Asia              Master's                  Y
# 25478  EZYV25479           Asia              Master's                  Y
# 25479  EZYV25480           Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
pd.concat([ non_outliers_df, modified_df])
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 0         EZYV01           Asia           High School                  N
# 1         EZYV02           Asia              Master's                  Y
# 2         EZYV03           Asia            Bachelor's                  N
# 3         EZYV04           Asia            Bachelor's                  N
# 4         EZYV05         Africa              Master's                  Y
# ...          ...            ...                   ...                ...
# 25191  EZYV25192           Asia              Master's                  N
# 25195  EZYV25196  North America              Master's                  Y
# 25468  EZYV25469           Asia            Bachelor's                  N
# 25469  EZYV25470  North America              Master's                  Y
# 25476  EZYV25477           Asia           High School                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
plt.boxplot(final_df["prevailing_wage"])
plt.title("Without outliers")
plt.show()

# %%
plt.boxplot(visa_df["prevailing_wage"])
plt.title("With outliers")
plt.show()

# %% [markdown]
# # np.where

# %% [markdown]
# - np.where is used to fill the values based on the true condition
#
# - np.where will take 3 arguments
#
#      - condition
#
#      - Value you want to replace if the con is true
#
#      - Value you want to replace if the cond is false

# %% [markdown]
# **np.where(condition,True val,False val)**

# %%
d1=pd.DataFrame()
d1["Name"]=["shiv","ram","raj"]
d1["age"]=[23,35,35]
# in the age col > 25 i want to replace with 300
con=d1["age"]>25
# when condition is True : 300
# False : keep it as it is
d1['age']=np.where(con,300,d1["age"])
d1
# Out:
#    Name  age
# 0  shiv   23
# 1   ram  300
# 2   raj  300

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_location="C:\\Users\\Greeshma\\OneDrive\\Naresh IT\\files\\Visadataset - Visadataset.csv"
visa_df=pd.read_csv(file_location)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
Q1=np.quantile(visa_df["prevailing_wage"],0.25)
Q2=np.quantile(visa_df["prevailing_wage"],0.50)
Q3=np.quantile(visa_df["prevailing_wage"],0.75)

IQR=Q3-Q1
UB=Q3+1.5*IQR
LB=Q1-1.5*IQR

############# Outliers_df #####################
con1=visa_df["prevailing_wage"]>UB
con2=visa_df["prevailing_wage"]<LB
con=con1 | con2
# visa_df[con]
med=visa_df["prevailing_wage"].median()
visa_df['prevailing_wage']=np.where(con,med,visa_df['prevailing_wage'])
plt.boxplot(visa_df["prevailing_wage"])
# outliers_df=visa_df[con1 | con2]
# med=visa_df["prevailing_wage"].median()
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d2bbf38250>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1d2bbf39510>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1d2bbf2b8d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1d2bbf3a690>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1d2bbf2afd0>],
#  'means': []}
