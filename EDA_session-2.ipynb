# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_location="C:\\Users\\Greeshma\\OneDrive\\Naresh IT\\files\\Visadataset - Visadataset.csv"
visa_df=pd.read_csv(file_location)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# **head**

# %%
# your name of the dataframe : visa_df
# package name.method name
visa_df.head() # it will return top 5
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %% [markdown]
# **tail**

# %%
visa_df.tail()  # it will gives last 5
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 25475                South         77092.57         Year                  Y
# ...

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# **shape**

# %%
visa_df.shape
# shape(m,n)
# m = 0 ===rows
# n =1 ====columns
# Out:
# (25480, 12)

# %%
visa_df.shape[0],visa_df.shape[1]
print("The number of rows are:",visa_df.shape[0])
print("The number of columns are:",visa_df.shape[1])
# Out:
# The number of rows are: 25480
# The number of columns are: 12

# %%
type(visa_df.shape)
# Out:
# tuple

# %% [markdown]
# **size**

# %%
- size is the number of entries

# %%
visa_df.size
# Out:
# 305760

# %%
visa_df.shape[0]*visa_df.shape[1]
# Out:
# 305760

# %% [markdown]
# **len**

# %%
len(visa_df)
# Out:
# 25480

# %% [markdown]
# **columns**

# %%
- It will provide all labels of 12 columns

# %%
cols=visa_df.columns
cols
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
type(cols)
# Out:
# pandas.core.indexes.base.Index

# %%
cols=visa_df.columns
for i in cols:
    print(i)
# Out:
# case_id
# continent
# education_of_employee
# has_job_experience
# requires_job_training
# no_of_employees
# yr_of_estab
# region_of_employment
# prevailing_wage
# unit_of_wage
# full_time_position
# case_status

# %%
col.to_list()
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'no_of_employees',
#  'yr_of_estab',
#  'region_of_employment',
#  'prevailing_wage',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
type(col.to_list())
# Out:
# list

# %% [markdown]
# **dtypes**

# %%
visa_df.dtypes
# Object : The values under the column are categorical
# Int/float : The values are numerical
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %%
case_id                   object
continent                 object
education_of_employee     object
has_job_experience        object
requires_job_training     object
no_of_employees            int64
yr_of_estab                int64
region_of_employment      object
prevailing_wage          float64
unit_of_wage              object
full_time_position        object
case_status               object
dtype: object
                    ################# This is the series type #############

# %%
type(visa_df.dtypes)
# Out:
# pandas.core.series.Series

# %% [markdown]
# **info**

# %%
visa_df.info()
# 25480 non-null  object  ===== there is no missing values that means no null values
#                                   null count=0  non null count=25480
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25480 entries, 0 to 25479
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   case_id                25480 non-null  object
#  1   continent              25480 non-null  object
#  2   education_of_employee  25480 non-null  object
#  3   has_job_experience     25480 non-null  object
#  4   requires_job_training  25480 non-null  object
#  5   no_of_employees        25480 non-null  int64
#  6   yr_of_estab            25480 non-null  int64
#  7   region_of_employment   25480 non-null  object
#  8   prevailing_wage        25480 non-null  float64
#  9   unit_of_wage           25480 non-null  object
#  10  full_time_position     25480 non-null  object
#  11  case_status            25480 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 2.3+ MB

# %% [markdown]
# **isnull**

# %%
visa_df.isnull()  # isnull ? It is a qn ==== it gives if null is there True if null is not there it gives False
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %%
visa_df.isna()
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %%
visa_df.isnull()
visa_df.isna()     ############## Both are same ##################

# %%
visa_df.isna().sum()
# Out:
# case_id                  0
# continent                0
# education_of_employee    0
# has_job_experience       0
# requires_job_training    0
# no_of_employees          0
# yr_of_estab              0
# region_of_employment     0
# prevailing_wage          0
# unit_of_wage             0
# full_time_position       0
# case_status              0
# dtype: int64

# %%
visa_df.columns()
# The error is ==='Index' object is not callable==== 
# NOt Callable means it is not a function
# The functions only callabale 
# so remove ()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 visa_df.columns()
#
# TypeError: 'Index' object is not callable

# %%
visa_df.head 
# in this 
# <bound method NDFrame.head of          case_id continent education_of_employee has_job_experience  \
# bound method or builtin function 
# provide brackets
# Out:
# <bound method NDFrame.head of          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# - Not Callable
#    - The error is ==='Index' object is not callable====
#    -  NOt Callable means it is not a function
#    - The functions only callabale
#    - so remove ()
# - Bound or Built in
#    - bound method NDFrame.head of          case_id continent education_of_employee has_job_experience  \
#    - bound method or builtin function
#    - provide brackets

# %%
visa_df.dtypes
# I want to separate categorical columns and numerical columns
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %%
dict1=dict(visa_df.dtypes)
cat=[]
num=[]
for i in dict1:
    if dict1[i]=="object":
        cat.append(i)
    elif dict1[i]!="object":
        num.append(i)
    else:
        print("None")
print(cat)
print(num)
# Out:
# ['case_id', 'continent', 'education_of_employee', 'has_job_experience', 'requires_job_training', 'region_of_employment', 'unit_of_wage', 'full_time_position', 'case_status']
# ['no_of_employees', 'yr_of_estab', 'prevailing_wage']

# %%
dict1=dict(visa_df.dtypes)
cat=[i for i in dict1 if dict1[i]=="object"]
num=[i for i in dict1 if dict1[i]!="object"]
cat,num
# Out:
# (['case_id',
#   'continent',
#   'education_of_employee',
#   'has_job_experience',
#   'requires_job_training',
#   'region_of_employment',
#   'unit_of_wage',
#   'full_time_position',
#   'case_status'],
#  ['no_of_employees', 'yr_of_estab', 'prevailing_wage'])

# %%
# This is the another easy way by using select_dtypes
print(visa_df.select_dtypes(include='object').columns)
print(visa_df.select_dtypes(exclude='object').columns)
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %% [markdown]
# **take loc and iloc**

# %%
visa_df.take()
# error 'indices'
# indices ==== rows
# indices is an array
# it is an array so provide a list
# by default axis = 0
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 visa_df.take()
#
# TypeError: NDFrame.take() missing 1 required positional argument: 'indices'

# %%
visa_df.take([1])
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 1  EZYV02      Asia              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 1                     N             2412         2002            Northeast
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 1         83425.65         Year                  Y   Certified

# %%
visa_df.take([0,1,2,4,5])
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
# 5  EZYV06      Asia              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 4                     N             1082         2005                South
# 5                     N             2339         2012                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
# change the axis=1
visa_df.take([0,1,2,3],axis=1)
# it gives 0,1,2,3 colums and all the rows
# Out:
#          case_id continent education_of_employee has_job_experience
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
# [25480 rows x 4 columns]

# %%
visa_df.take([100,200,300],axis=0)
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
visa_df.take([100,200,300]) # this is a small dataframe
# we want only 3 columns not all
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
visa_df.take([100,200,300]).take([1,2,3],axis=1)
# Out:
#     continent education_of_employee has_job_experience
# 100      Asia              Master's                  Y
# 200      Asia             Doctorate                  Y
# 300      Asia              Master's                  Y

# %%
visa_df.take([0,1,2,3,4,5])   # rows and all the columns
visa_df.take([0,1,2,3],axis=1)  # columns and all the rows
visa_df.take([100,200,300]).take([1,2,3],axis=1)  # rows and columns

# %%
- Read the data
- Quick checks 
- type : list ==== methods
         string ==== methods 
         dict ====== dict methods
         index ====has some methods =====convert into other 
- head/tail/shape/size
- columns/dtypes/info
- take === based on axis either rows or columns

# %% [markdown]
# **iloc**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_location="C:\\Users\\Greeshma\\OneDrive\\Naresh IT\\files\\Visadataset - Visadataset.csv"
visa_df=pd.read_csv(file_location)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df.iloc[rows,columns]
visa_df.iloc[<start:end>,<start:end]
visa_df.iloc[[rows index],[colums index]]

# %%
visa_df.iloc[2,1]  # in 1st column 2nd row element
# Out:
# 'Asia'

# %%
visa_df.iloc[5:10,2:6] # 5-9 rows and 2-5 columns
# Out:
#   education_of_employee has_job_experience requires_job_training  \
# 5              Master's                  Y                     N
# 6            Bachelor's                  N                     N
# 7            Bachelor's                  Y                     N
# 8            Bachelor's                  N                     N
# 9             Doctorate                  Y                     N
#
#    no_of_employees
# 5             2339
# 6             4985
# 7             3035
# 8             4810
# 9             2251

# %%
visa_df.iloc[5:9,6] #
# Out:
# 5    2012
# 6    1994
# 7    1924
# 8    2012
# Name: yr_of_estab, dtype: int64

# %%
visa_df.iloc[5:6,]
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 5  EZYV06      Asia              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 5                     N             2339         2012                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 5         78252.14         Year                  Y   Certified

# %%
visa_df.iloc[5:,]
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 5         EZYV06           Asia              Master's                  Y
# 6         EZYV07           Asia            Bachelor's                  N
# 7         EZYV08  North America            Bachelor's                  Y
# 8         EZYV09           Asia            Bachelor's                  N
# 9         EZYV10         Europe             Doctorate                  Y
# ...          ...            ...                   ...                ...
# 25475  EZYV25476           Asia            Bachelor's                  Y
# 25476  EZYV25477           Asia           High School                  Y
# 25477  EZYV25478           Asia              Master's                  Y
# 25478  EZYV25479           Asia              Master's                  Y
# 25479  EZYV25480           Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
visa_df.iloc[5:,6]
# Out:
# 5        2012
# 6        1994
# 7        1924
# 8        2012
# 9        1995
#          ...
# 25475    2008
# 25476    2006
# 25477    1910
# 25478    1887
# 25479    1960
# Name: yr_of_estab, Length: 25475, dtype: int64

# %%
visa_df.iloc[0:,0:]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df.iloc[ :,]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df.iloc[:,]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df.iloc[:]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
# specific rows and columns
rows= [100,200,300]
cols=[2,7]
visa_df.iloc[rows,cols]
# Out:
#     education_of_employee region_of_employment
# 100              Master's            Northeast
# 200             Doctorate                 West
# 300              Master's              Midwest

# %%
rows= [100,200,300]
visa_df.iloc[rows,2:9]
# Out:
#     education_of_employee has_job_experience requires_job_training  \
# 100              Master's                  Y                     N
# 200             Doctorate                  Y                     N
# 300              Master's                  Y                     N
#
#      no_of_employees  yr_of_estab region_of_employment  prevailing_wage
# 100             2227         2007            Northeast         28243.79
# 200             3282         1979                 West         74441.11
# 300             3268         2012              Midwest        101371.21

# %%
rows= [100,200,300]
cols=["education_of_employee","requires_job_training"]
visa_df.iloc[rows,cols]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[28], line 3
#       1 rows= [100,200,300]
#       2 cols=["education_of_employee","requires_job_training"]
# ----> 3 visa_df.iloc[rows,cols]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1097, in _LocationIndexer.__getitem__(self, key)
#    1095     if self._is_scalar_access(key):
#    1096         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1097     return self._getitem_tuple(key)
#    1098 else:
#    1099     # we by definition only have the 0th axis
#    1100     axis = self.axis or 0
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1594, in _iLocIndexer._getitem_tuple(self, tup)
#    1593 def _getitem_tuple(self, tup: tuple):
# -> 1594     tup = self._validate_tuple_indexer(tup)
#    1595     with suppress(IndexingError):
# ...

# %%
- iloc takes only numerical entry , we can not provide column names directly 
- to avoid this problem we can use loc

# %% [markdown]
# **loc**

# %%
- loc takes only column names

# %%
rows= [100,200,300]
cols=["education_of_employee","requires_job_training"]
visa_df.loc[rows,cols]
# Out:
#     education_of_employee requires_job_training
# 100              Master's                     N
# 200             Doctorate                     N
# 300              Master's                     N

# %%
rows= [100,200,300]
cols=["requires_job_training"]
visa_df.loc[rows,cols]
# Out:
#     requires_job_training
# 100                     N
# 200                     N
# 300                     N
