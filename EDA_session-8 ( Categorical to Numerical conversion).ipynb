# %% [markdown]
# # Categorical to Numerical conversion

# %% [markdown]
# - It is very important to convert categorical data to numerical data
#
# - Because all the ML models developed by using mathematics
#
# - If you try to implement ML algorithm development using Cat col it will fail
#
# - Methods
#
#     - Manually by using map method
#
#     - One hot encoder : pd.get_dummies-
#
#     - Label encode: Sickit learn package

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_location="C:\\Users\\Greeshma\\OneDrive\\Naresh IT\\files\\Visadataset - Visadataset.csv"
visa_df=pd.read_csv(file_location)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# # Manually by using map method #

# %% [markdown]
# **Map method** - **Case status**

# %% [markdown]
# - First consider one categorical column
#
# - Observe how many unique lables are there
#
# - Assume here we are taking case_status column
#
# - case_status two unique labels
#
#     - Denied
#
#     - Certified
#
# - Create a dictionary by providing key:value
#
# - Here key = Denied and value = 1
#
# - Key = Certified and value = 0
#
# - dictionary will looks : {"certified":0 , "Denied":1}

# %%
visa_df["case_status"].unique()
# Out:
# array(['Denied', 'Certified'], dtype=object)

# %%
d1={"Certified":0 , "Denied":1}
visa_df["case_status"].map(d1)
# Out:
# 0        1
# 1        0
# 2        1
# 3        1
# 4        0
#         ..
# 25475    0
# 25476    0
# 25477    0
# 25478    0
# 25479    0
# Name: case_status, Length: 25480, dtype: int64

# %%
# After mapping in which column you want to apply the data 
# You want to create a new col or 
# you want to use old col
# it is our wish completely
visa_df["case_status"]=visa_df["case_status"].map(d1)
visa_df["case_status"]
# Out:
# 0        1
# 1        0
# 2        1
# 3        1
# 4        0
#         ..
# 25475    0
# 25476    0
# 25477    0
# 25478    0
# 25479    0
# Name: case_status, Length: 25480, dtype: int64

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df["continent"].unique()
# Out:
# array(['Asia', 'Africa', 'North America', 'Europe', 'South America',
#        'Oceania'], dtype=object)

# %%
d2={'Asia':0, 'Africa':1, 'North America':2, 'Europe':3, 'South America':4,'Oceania':5}
visa_df["continent"]=visa_df["continent"].map(d1)
visa_df.head()
# Out:
#   case_id  continent education_of_employee has_job_experience  \
# 0  EZYV01        NaN           High School                  N
# 1  EZYV02        NaN              Master's                  Y
# 2  EZYV03        NaN            Bachelor's                  N
# 3  EZYV04        NaN            Bachelor's                  N
# 4  EZYV05        NaN              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position  case_status
# 0         592.2029         Hour                  Y            1
# ...

# %%
d1={}
labels=visa_df["continent"].unique()
for i in range(len(labels)):
    d1[labels[i]]=i
d1
# Out:
# {nan: 0}

# %%
visa_df["continent"]=visa_df["continent"].map(d1)
visa_df.head()
# Out:
#   case_id  continent education_of_employee has_job_experience  \
# 0  EZYV01          0           High School                  N
# 1  EZYV02          0              Master's                  Y
# 2  EZYV03          0            Bachelor's                  N
# 3  EZYV04          0            Bachelor's                  N
# 4  EZYV05          0              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position  case_status
# 0         592.2029         Hour                  Y            1
# ...

# %% [markdown]
# # Method-2 #

# %%
file_location="C:\\Users\\Greeshma\\OneDrive\\Naresh IT\\files\\Visadataset - Visadataset.csv"
visa_df=pd.read_csv(file_location)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# - np.where is a kind of if-else
#
# - np.where is useful for binary condition
#
# - which means it is use only if the labels are two
#
# - np.where takes three parameters
#
#     - condition
#
#     - True value
#
#     - False value
#
# - I want to replace case status column with 1 when it is Denied
#
# - Otherwise it is a 0
#
# - con=visa_df["case_status"]=="Denied"
#
# - True value = 1 False val=0
#
# -np.where(con,True val ,False val)

# %%
np.where(visa_df["case_status"]=="Denied",1,0)
# Out:
# array([1, 0, 1, ..., 0, 0, 0])

# %%
visa_df["case_status"]=np.where(visa_df["case_status"]=="Denied",1,0)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# # Method -3 #

# %% [markdown]
# **One hot encoder**

# %% [markdown]
# **pd.get_dummies()**

# %% [markdown]
# - one hot encoder means at a time only one will be ON and , Other will be OFF
#
# - ON reperesents with 1 and OFF represents 0
#
# - One hot encoder creates new extra  column based on labels in the columns
#
# - For example case_status has two unique labels
#
# - If you apply one hot encoder on case_status it creates two extra columns
#
#     - case_status_Denied
#
#     - case_status_Certified
#
# |case_status| case_status_Denied | case_status_Certified |
# ------------|--------------------| ----------------------|
# | case_status_Denied | 1 | 0 |
# |case_status_Certified | 0 | 1 |
#
#
# **Advantages**
#
# -  One hot encoder gives independency between the variables
#
# - It is one of the important property before apply ML models
#
# - Variables are independent to each other
#
# - Variables Are perpendicular to each other
#
# - Variables are 90 degrees phase shift
#
# - Variables are Orthogonal each other
#
# **Disadvantages**
#
# - Assume that a column has 100 unique labels
#
# - If we apply one hot encoder it will creates 100 new columns along with prvious columns
#
# - your data matrix becomes parse
#
# - We required more time more memory to compute the calculation
#
# - This is called **Curse of Dimensionality**
#
# -

# %%
file_location="C:\\Users\\Greeshma\\OneDrive\\Naresh IT\\files\\Visadataset - Visadataset.csv"
visa_df=pd.read_csv(file_location)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
# Drop the ID's column before apply ML models and in this hot encoder also
# case id's are having unique labels 
# in this df we have 25480 unique id's are there sowe will get 25480+12 cols when we apply the pd.get_dummies()
# So drop the id's
# Id's does not give any information
visa_df.drop("case_id",axis=1,inplace=True)
visa_df
# Out:
#       continent education_of_employee has_job_experience  \
# 0          Asia           High School                  N
# 1          Asia              Master's                  Y
# 2          Asia            Bachelor's                  N
# 3          Asia            Bachelor's                  N
# 4        Africa              Master's                  Y
# ...         ...                   ...                ...
# 25475      Asia            Bachelor's                  Y
# 25476      Asia           High School                  Y
# 25477      Asia              Master's                  Y
# 25478      Asia              Master's                  Y
# 25479      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# ...

# %%
pd.get_dummies(visa_df,dtype="int")
# Out:
#        no_of_employees  yr_of_estab  prevailing_wage  continent_Africa  \
# 0                14513         2007         592.2029                 0
# 1                 2412         2002       83425.6500                 0
# 2                44444         2008      122996.8600                 0
# 3                   98         1897       83434.0300                 0
# 4                 1082         2005      149907.3900                 1
# ...                ...          ...              ...               ...
# 25475             2601         2008       77092.5700                 0
# 25476             3274         2006      279174.7900                 0
# 25477             1121         1910      146298.8500                 0
# 25478             1918         1887       86154.7700                 0
# 25479             3195         1960       70876.9100                 0
#
#        continent_Asia  continent_Europe  continent_North America  \
# ...

# %% [markdown]
# # Method-4 #

# %% [markdown]
# **label encoder**

# %% [markdown]
# - we already implemented map method by our own
#
# - The same map method is done by using package
#
# - Package name : **sklearn**
#
# - Method name : **LabelEncoder**
#
# - sklearn package approach is very
#
#     - step-1 : Read the package
#
#     - step-2 : Save the package
#
#     - step-3 : Apply fit transform

# %%
file_location="C:\\Users\\Greeshma\\OneDrive\\Naresh IT\\files\\Visadataset - Visadataset.csv"
visa_df=pd.read_csv(file_location)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
file_location="C:\\Users\\Greeshma\\OneDrive\\Naresh IT\\files\\Visadataset - Visadataset.csv"
visa_df=pd.read_csv(file_location)
print(visa_df["continent"].values[:10])
# read the pacakge
from sklearn.preprocessing import LabelEncoder
# save the packae
le=LabelEncoder()
# apply fit_transform
visa_df["continent"]=le.fit_transform(visa_df["continent"])
visa_df.head()
# Out:
# ['Asia' 'Asia' 'Asia' 'Asia' 'Africa' 'Asia' 'Asia' 'North America' 'Asia'
#  'Europe']
#   case_id  continent education_of_employee has_job_experience  \
# 0  EZYV01          1           High School                  N
# 1  EZYV02          1              Master's                  Y
# 2  EZYV03          1            Bachelor's                  N
# 3  EZYV04          1            Bachelor's                  N
# 4  EZYV05          0              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
# ...

# %%
# for region_of_employment col

# %%
file_location="C:\\Users\\Greeshma\\OneDrive\\Naresh IT\\files\\Visadataset - Visadataset.csv"
visa_df=pd.read_csv(file_location)
print(visa_df["region_of_employment"].values[:10])
# read the pacakge
from sklearn.preprocessing import LabelEncoder
# save the packae
le=LabelEncoder()
# apply fit_transform
visa_df["region_of_employment"]=le.fit_transform(visa_df["region_of_employment"])
visa_df.head()
# Out:
# ['West' 'Northeast' 'West' 'West' 'South' 'South' 'South' 'West' 'Midwest'
#  'South']
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab  region_of_employment  \
# 0                     N            14513         2007                     4
# 1                     N             2412         2002                     2
# 2                     Y            44444         2008                     4
# 3                     N               98         1897                     4
# 4                     N             1082         2005                     3
#
# ...

# %%
# applying for entire df
file_location="C:\\Users\\Greeshma\\OneDrive\\Naresh IT\\files\\Visadataset - Visadataset.csv"
visa_df=pd.read_csv(file_location)
print(visa_df)
# read the pacakge
from sklearn.preprocessing import LabelEncoder
# save the packae
le=LabelEncoder()
# apply fit_transform
visa_df=le.fit_transform([visa_df])
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
# we cant apply directly
file_location="C:\\Users\\Greeshma\\OneDrive\\Naresh IT\\files\\Visadataset - Visadataset.csv"
visa_df=pd.read_csv(file_location)
# print(visa_df)
# read the pacakge
from sklearn.preprocessing import LabelEncoder
# save the packae
le=LabelEncoder()
# apply fit_transform
# we cant apply directly
# use loop
cat_cols=visa_df.select_dtypes(include='object').columns
for i in cat_cols:
    visa_df[i]=le.fit_transform(visa_df[i])
visa_df.head()
# Out:
#    case_id  continent  education_of_employee  has_job_experience  \
# 0        0          1                      2                   0
# 1        1          1                      3                   1
# 2        2          1                      0                   0
# 3        3          1                      0                   0
# 4        4          0                      3                   1
#
#    requires_job_training  no_of_employees  yr_of_estab  region_of_employment  \
# 0                      0            14513         2007                     4
# 1                      0             2412         2002                     2
# 2                      1            44444         2008                     4
# 3                      0               98         1897                     4
# 4                      0             1082         2005                     3
#
#    prevailing_wage  unit_of_wage  full_time_position  case_status
# ...

# %% [markdown]
# # inverse transform #

# %%
print(visa_df["case_status"][:5])
# we are trying to check what is 1 and 0 
# le is label encoder we already assigned to le
le.inverse_transform(visa_df["case_status"])[:5]
# Out:
# 0    1
# 1    0
# 2    1
# 3    1
# 4    0
# Name: case_status, dtype: int32
# array(['Denied', 'Certified', 'Denied', 'Denied', 'Certified'],
#       dtype=object)
