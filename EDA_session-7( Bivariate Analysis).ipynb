# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_location="C:\\Users\\Greeshma\\OneDrive\\Naresh IT\\files\\Visadataset - Visadataset.csv"
visa_df=pd.read_csv(file_location)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# **Categorical VS Categorical**

# %%
# Column name : continent
# output column : Case status
visa_df['continent'].value_counts()
# Out:
# continent
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: count, dtype: int64

# %%
# I want to know out of 16861 members how many got the visa 
# we are analysing continent and case status
con1=visa_df["continent"]=="Asia"
con1
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4        False
#          ...
# 25475     True
# 25476     True
# 25477     True
# 25478     True
# 25479     True
# Name: continent, Length: 25480, dtype: bool

# %%
con2=visa_df["case_status"]=="Certified"
con2
# Out:
# 0        False
# 1         True
# 2        False
# 3        False
# 4         True
#          ...
# 25475     True
# 25476     True
# 25477     True
# 25478     True
# 25479     True
# Name: case_status, Length: 25480, dtype: bool

# %%
con=con1&con2
visa_df[con]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 1         EZYV02      Asia              Master's                  Y
# 5         EZYV06      Asia              Master's                  Y
# 6         EZYV07      Asia            Bachelor's                  N
# 8         EZYV09      Asia            Bachelor's                  N
# 10        EZYV11      Asia              Master's                  N
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 1                         N             2412         2002
# ...

# %%
con3=con1|con2
visa_df[con3]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df[(visa_df['continent']=='Asia') & (visa_df["case_status"]=="Certified")]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 1         EZYV02      Asia              Master's                  Y
# 5         EZYV06      Asia              Master's                  Y
# 6         EZYV07      Asia            Bachelor's                  N
# 8         EZYV09      Asia            Bachelor's                  N
# 10        EZYV11      Asia              Master's                  N
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 1                         N             2412         2002
# ...

# %%
visa_df[(visa_df['continent']=='Asia') & (visa_df["case_status"]=="Denied")]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 11        EZYV12      Asia           High School                  Y
# 15        EZYV16      Asia           High School                  Y
# ...          ...       ...                   ...                ...
# 25450  EZYV25451      Asia            Bachelor's                  N
# 25452  EZYV25453      Asia           High School                  N
# 25454  EZYV25455      Asia            Bachelor's                  N
# 25459  EZYV25460      Asia           High School                  Y
# 25461  EZYV25462      Asia              Master's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
con1=visa_df["continent"]=="Asia"
con2=visa_df["case_status"]=="Certified"
con3=visa_df["case_status"]=="Denied"
cert=con1&con2
denied=con1&con3
len(visa_df[cert]),len(visa_df[denied])
print(f"{len(visa_df[cert])} are got visa from Asia")
print(f"{len(visa_df[denied])} got rejected the visa from Asia")
# Out:
# 11012 are got visa from Asia
# 5849 got rejected the visa from Asia

# %%
labels=visa_df["continent"].value_counts().keys()
for i in labels:
    con1=visa_df["continent"]==i
    con2=visa_df["case_status"]=="Certified"
    con3=visa_df["case_status"]=="Denied"
    cert=con1&con2
    den=con1&con3
    print(f"{len(visa_df[cert])} are got visa from {i}")
    print(f"{len(visa_df[den])} got rejected the visa from {i}")
# Out:
# 11012 are got visa from Asia
# 5849 got rejected the visa from Asia
# 2957 are got visa from Europe
# 775 got rejected the visa from Europe
# 2037 are got visa from North America
# 1255 got rejected the visa from North America
# 493 are got visa from South America
# 359 got rejected the visa from South America
# 397 are got visa from Africa
# 154 got rejected the visa from Africa
# 122 are got visa from Oceania
# 70 got rejected the visa from Oceania

# %%
labels=visa_df["continent"].value_counts().keys()
certified=[]
denied=[]
for i in labels:
    con1=visa_df["continent"]==i
    con2=visa_df["case_status"]=="Certified"
    con3=visa_df["case_status"]=="Denied"
    cert=con1&con2
    den=con1&con3
    len(visa_df[cert]),len(visa_df[den])
    certified.append(len(visa_df[cert]))
    denied.append(len(visa_df[den]))
pd.DataFrame(zip(labels,certified,denied),
             columns=["continent","certified","Denied"])
# Out:
#        continent  certified  Denied
# 0           Asia      11012    5849
# 1         Europe       2957     775
# 2  North America       2037    1255
# 3  South America        493     359
# 4         Africa        397     154
# 5        Oceania        122      70

# %% [markdown]
# **Crosstab**

# %%
col1=visa_df['continent']
col2=visa_df['case_status']
result1=pd.crosstab(col1,col2)
result1
# Out:
# case_status    Certified  Denied
# continent
# Africa               397     154
# Asia               11012    5849
# Europe              2957     775
# North America       2037    1255
# Oceania              122      70
# South America        493     359

# %%
 result1.plot()
# Out:
# <Axes: xlabel='continent'>

# %%
result1.plot(kind='bar')
plt.show()

# %%
# will take three columns
col1=visa_df['continent']
col2=visa_df['case_status']
result1=pd.crosstab(col1,col2)
result1



# pd.crosstab(
#     index,
#     columns,
#     values=None,
#     rownames=None,
#     colnames=None,
#     aggfunc=None,


# col1= index
# col2= columns

# %%
col1=visa_df['continent']
col2=[visa_df['case_status'],visa_df["education_of_employee"]]
result2=pd.crosstab(col1,col2)
result2
# Out:
# case_status            Certified                                    Denied  \
# education_of_employee Bachelor's Doctorate High School Master's Bachelor's
# continent
# Africa                        81        43          23      250         62
# Asia                        4407       780         676     5149       2761
# Europe                      1040       788         162      967        259
# North America                641       207         210      979        584
# Oceania                       38        19          19       46         28
# South America                160        75          74      184        173
#
# case_status
# education_of_employee Doctorate High School Master's
# continent
# Africa                       11          43       38
# Asia                        143        1614     1331
# Europe                       58         328      130
# North America                51         191      429
# Oceania                       3          17       22
# ...

# %%
col1=visa_df['continent']
col2=[visa_df["education_of_employee"],visa_df['case_status']]
result3=pd.crosstab(col1,col2)
result3
# Out:
# education_of_employee Bachelor's        Doctorate        High School         \
# case_status            Certified Denied Certified Denied   Certified Denied
# continent
# Africa                        81     62        43     11          23     43
# Asia                        4407   2761       780    143         676   1614
# Europe                      1040    259       788     58         162    328
# North America                641    584       207     51         210    191
# Oceania                       38     28        19      3          19     17
# South America                160    173        75     14          74     63
#
# education_of_employee  Master's
# case_status           Certified Denied
# continent
# Africa                      250     38
# Asia                       5149   1331
# Europe                      967    130
# North America               979    429
# Oceania                      46     22
# South America               184    109

# %%
# will take three cols

# %%
col1=visa_df['continent']
col2=[visa_df['case_status'],visa_df["education_of_employee"],visa_df["has_job_experience"]]
result4=pd.crosstab(col1,col2)
result4
# Out:
# case_status            Certified                                        \
# education_of_employee Bachelor's       Doctorate      High School
# has_job_experience             N     Y         N    Y           N    Y
# continent
# Africa                        32    49        14   29           8   15
# Asia                        1495  2912       301  479         276  400
# Europe                       418   622       325  463          70   92
# North America                216   425        70  137          57  153
# Oceania                       18    20        10    9           5   14
# South America                 52   108        34   41          26   48
#
# case_status                              Denied                      \
# education_of_employee Master's       Bachelor's       Doctorate
# has_job_experience           N     Y          N     Y         N   Y
# continent
# Africa                      79   171         32    30         8   3
# ...

# %%
result2.plot()
# Out:
# <Axes: xlabel='continent'>

# %%
result2.plot(kind='bar')
# Out:
# <Axes: xlabel='continent'>

# %% [markdown]
# # Numerical VS Numerical #

# %% [markdown]
# **Scatter plots**

# %% [markdown]
# - plt.scatter
#
# - will take two arguments  x - axis and y - axis
#
# - both variables should be numerical
#
# - it provides relathon between 2 variables
#
#     - positively related
#
#     - negatively related
#
#     - no relation

# %%
x=[1,2,3,4,5]
y=[11,22,33,44,55]
plt.scatter(x,y)
plt.show()

# %% [markdown]
# **Line plot**

# %%
x=[1,2,3,4,5]
y=[11,22,33,44,55]
plt.scatter(x,y)                      # Positively  correlated
plt.plot(x,y)
plt.show()

# %%
x=[1,4,9,16,25]
y=[1,2,3,4,5]
plt.scatter(x,y)
plt.show()

# %%
# y=x^2
x=[1,4,9,16,25]
y=[1,2,3,4,5]
plt.scatter(x,y)
plt.plot(x,y)
plt.show()

# %%
# x=y^2
x=[i for i in range(1,5)]
y=[i * i for i in range(1,5)]
plt.scatter(x,y)
plt.plot(x,y)
plt.show()

# %%
# x=y^2
x=[i for i in range(-4,5)]
y=[i * i for i in range(-4,5)]
plt.scatter(x,y)
plt.plot(x,y)
plt.show()

# %%
x=[10,9,3,2,1]
y=[-3,-4,-6,-8,-2]
plt.scatter(x,y)
plt.plot(x,y)
plt.show()

# %% [markdown]
# **Scatter plot on two numerical cols in visa_df**

# %%
x=visa_df["prevailing_wage"]
y=visa_df["no_of_employees"]
plt.scatter(x,y)

plt.show()

# %%
x=visa_df["prevailing_wage"]
y=visa_df["no_of_employees"]
plt.scatter(x,y)
plt.plot(x,y)
plt.show()

# %% [markdown]
# **Correlation-Coefficient**
#
#  - Denoted with r
#
#   - Pearson Correlation Coefficient
#
#   - r varies from -1 to 1
#
#   - r= -1 to 0 : Negatively correlated
#
#   - r= 0 to 1  : Positively correlated
#
#   - r= 0 : No relation

# %%
visa_df.corr(numeric_only=True)
# Out:
#                  no_of_employees  yr_of_estab  prevailing_wage
# no_of_employees         1.000000    -0.017770        -0.009523
# yr_of_estab            -0.017770     1.000000         0.012342
# prevailing_wage        -0.009523     0.012342         1.000000

# %%
file_location="C:\\Users\\Greeshma\\OneDrive\\Naresh IT\\files\\winequality_red - winequality_red.csv"
wine_df=pd.read_csv(file_location)
wine_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               NaN               NaN          NaN             NaN        NaN
# 1               7.4             0.700         0.00             1.9      0.076
# 2               NaN               NaN          NaN             NaN        NaN
# 3               7.8             0.880         0.00             2.6      0.098
# 4               NaN               NaN          NaN             NaN        NaN
# ...             ...               ...          ...             ...        ...
# 3193            6.3             0.510         0.13             2.3      0.076
# 3194            NaN               NaN          NaN             NaN        NaN
# 3195            5.9             0.645         0.12             2.0      0.075
# 3196            NaN               NaN          NaN             NaN        NaN
# 3197            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
wine_df.corr(numeric_only=True)
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %% [markdown]
# **Heatmap**

# %% [markdown]
# - It is a two dimensional graphical representation of data , each value in a matrix is represented by a different colour.
# - it is very easy to understand the graphical representation
# - sns.heatmap(<co variance matrix>)
# - heat map available from seaborn package
# - line your right min=0 max=1
# - entire matrix ranges 0 to 1 only

# %%
corr=visa_df.corr(numeric_only=True)
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
corr=visa_df.corr(numeric_only=True)
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
corr=wine_df.corr(numeric_only=True)
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
plt.scatter(wine_df["fixed acidity"],wine_df['fixed acidity'])   # positively correlated

# %%
plt.scatter(wine_df["fixed acidity"],wine_df["volatile acidity"])   # Negatively correlated

# %%
x=7
y=2
x if x > y else y
# Out:
# 7

# %%
x=1
y=2
if x>y: print(x)

# %%
for i in range(0,3):
    for j in range(i+1):
        print("*",end=" ")
    print()
# Out:
# *
# * *
# * * *

# %%
# rows=5
for i in range(6,0,-1):
    for j in range(0i-1): 
        print("*",end=" ")
    print()
# Out:
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
for i in range(0,3):
    print(i)
# Out:
# 0
# 1
# 2
